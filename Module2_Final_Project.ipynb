# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tewodros Dessalegn**

# %% [markdown]
# Researcher

# %% [markdown]
# *I am interested in data science because I love to gain insightful information obtained from data*

# %% [markdown]
# ### The following code tests the Gauss formula

# %%
def gauss (n):
    return (n*(n+1))/2
gauss(100)==sum(range(101))
# Out:
# True

# %% [markdown]
#  - January
#  - Febraury
#  - March

# %% [markdown]
# 1. September
# 2. October
# 3. November
# 4. December

# %% [markdown]
# ~~I am getting smarter~~
